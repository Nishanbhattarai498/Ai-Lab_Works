# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X = np.arange(10,20,0.13)
print(X[:3])
y=1.229*X + 9.887
print(y[:3])
print(len(X) ,len(y))
# Out:
# [10.   10.13 10.26]
# [22.177   22.33677 22.49654]
# 77 77

# %%
split =int(len(X)*0.8)
print(split)
X_train, y_train =X[:split],y[:split]
X_test ,y_test =X[split:],y[split:]
# Out:
# 61

# %%
def plot_data(X_train=X_train,y_train=y_train,
              X_test=X_test,y_test=y_test,
              predictions=None
              ):
    plt.scatter(X_train,y_train , c='b',label='Training Data')
    plt.scatter(X_test,y_test , c='r',label='Testing Data')

    if predictions is not None:
        plt.plot(X_test,predictions,c='g',label='Predictions')

    plt.xlabel('X')
    plt.ylabel('y')
    plt.title('X vs y')
    plt.legend()
    plt.show()

plot_data()

# %%
w=np.random.randn()
b=np.random.randn()
print(f'Initially w={w} and b={b}')
# Out:
# Initially w=0.6900932484019525 and b=0.2743365058128903

# %%
def loss_fn(y_actual,y_out):
    return np.sum(np.square((y_actual-y_out)))/len(y_actual)

# %%
y_out=X_test*w + b
plot_data(predictions=y_out)

# %%
lr= 0.0001
epochs =300
train_loss_list =[]
test_loss_list=[]
for epoch in range(epochs):
    #forward pass
    train_preds =X_train*w +b

    # compute the loss 
    train_loss = loss_fn(y_actual=y_train,y_out=train_preds)
    #compute the Gradients

    gradientW=  (-2/len(X_train))*np.sum((y_train -train_preds)*X_train)
     
    gradientb=  (-2/len(X_train))*np.sum((y_train -train_preds))

    #Backpropagate

    w= w - gradientW *lr
    b= b - gradientb *lr

    #testing

    test_preds =X_test*w +b 
    test_loss =loss_fn(y_actual=y_test, y_out=test_preds)
    if (epoch+1)%10 == 0:
        print(f'Epoch {epoch+1} | Train loss {train_loss:.4f} | Train loss{test_loss:.4f}')

    train_loss_list.append (train_loss)
    test_loss_list.append(test_loss)
# Out:
# Epoch 10 | Train loss 2.4348 | Train loss8.1533
# Epoch 20 | Train loss 2.4118 | Train loss8.6542
# Epoch 30 | Train loss 2.4015 | Train loss8.9956
# Epoch 40 | Train loss 2.3968 | Train loss9.2262
# Epoch 50 | Train loss 2.3945 | Train loss9.3810
# Epoch 60 | Train loss 2.3934 | Train loss9.4845
# Epoch 70 | Train loss 2.3928 | Train loss9.5533
# Epoch 80 | Train loss 2.3924 | Train loss9.5989
# Epoch 90 | Train loss 2.3920 | Train loss9.6290
# Epoch 100 | Train loss 2.3917 | Train loss9.6487
# Epoch 110 | Train loss 2.3915 | Train loss9.6615
# Epoch 120 | Train loss 2.3912 | Train loss9.6697
# Epoch 130 | Train loss 2.3910 | Train loss9.6748
# Epoch 140 | Train loss 2.3907 | Train loss9.6779
# Epoch 150 | Train loss 2.3905 | Train loss9.6796
# Epoch 160 | Train loss 2.3902 | Train loss9.6803
# Epoch 170 | Train loss 2.3900 | Train loss9.6805
# Epoch 180 | Train loss 2.3897 | Train loss9.6803
# Epoch 190 | Train loss 2.3895 | Train loss9.6798
# Epoch 200 | Train loss 2.3892 | Train loss9.6792
# Epoch 210 | Train loss 2.3890 | Train loss9.6784
# Epoch 220 | Train loss 2.3887 | Train loss9.6775
# Epoch 230 | Train loss 2.3884 | Train loss9.6766
# Epoch 240 | Train loss 2.3882 | Train loss9.6757
# Epoch 250 | Train loss 2.3879 | Train loss9.6747
# Epoch 260 | Train loss 2.3877 | Train loss9.6737
# Epoch 270 | Train loss 2.3874 | Train loss9.6727
# Epoch 280 | Train loss 2.3872 | Train loss9.6717
# Epoch 290 | Train loss 2.3869 | Train loss9.6707
# Epoch 300 | Train loss 2.3867 | Train loss9.6697

# %%
#plot Loss Curves
plt.plot(range(epochs),train_loss_list,label="Training Loss")
plt.plot(range(epochs),test_loss_list,label="Testing Loss")
plt.title("Epochs vs Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
print(f'Finally')
# Out:
# Finally
